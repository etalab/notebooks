# %% [markdown]
# **Executed:** Wed Apr 29 08:00:02 2020<br>**Duration:** 12 seconds.<br>**Autogenerated from:** [/root/notebooks/moderation/moderation.ipynb](output/moderation/moderation_20200429-080002.ipynb)
#
# ---

# %% [markdown]
# # Modération / stats data.gouv.fr
#
# Affiche les derniers objets (datasets, reuses, commentaires, utilisateurs) créés depuis `start_date` (via l'API publique).

# %%
import os
from pathlib import Path

# %%
DOMAIN = 'www.data.gouv.fr'
PAGE_SIZE = 100
current_path = Path(os.getenv('WORKING_DIR')) if os.getenv('WORKING_DIR') else Path().absolute()
fn_path = '%s' % (current_path / 'moderation_fn.ipynb')
# %run $fn_path
# we want everything that happened since this date
start_date = datetime.now() - timedelta(days=1)
start_date
# Out:
# datetime.datetime(2020, 4, 28, 8, 0, 3, 246033)

# %% [markdown]
# ## Jeux de données

# %%
show_datasets()
# Out:
# <h3>7 jeux de données créés</h3>
# <a href="https://www.data.gouv.fr/fr/datasets/porteurs-de-projets-finances-par-le-fonds-departemental-daide-a-linitiative-des-jeunes-fdaij-du-conseil-departemental-du-finistere/" target="_blank">Porteurs de projets financés par le Fonds Départemental d'Aide à l'Initiative des Jeunes (FDAIJ) du Conseil départemental du Finistère</a> par <a href="https://www.data.gouv.fr/fr/organizations/conseil-departemental-du-finistere/" target="_blank">Conseil départemental du Finistère</a>
# <a href="https://www.data.gouv.fr/fr/datasets/beneficiaires-de-laide-a-la-formation-au-bafa-octroyee-par-le-conseil-departemental-du-finistere/" target="_blank">Bénéficiaires de l’aide à la formation au BAFA octroyée par le Conseil départemental du Finistère</a> par <a href="https://www.data.gouv.fr/fr/organizations/conseil-departemental-du-finistere/" target="_blank">Conseil départemental du Finistère</a>
# <a href="https://www.data.gouv.fr/fr/datasets/r0-pour-chaque-departement/" target="_blank">R0 pour chaque département</a> par <a href="https://www.data.gouv.fr/fr/users/jeremy-boyd/" target="_blank">Jeremy Boyd</a>
# <a href="https://www.data.gouv.fr/fr/datasets/niveaux-dexces-de-mortalite-standardise-durant-lepidemie-de-covid-19/" target="_blank">Niveaux d'excès de mortalité standardisé durant l'épidémie de COVID-19</a> par <a href="https://www.data.gouv.fr/fr/organizations/sante-publique-france/" target="_blank">Santé publique France</a>
# <a href="https://www.data.gouv.fr/fr/datasets/horaires-theoriques-et-temps-reel-du-reseau-annonay-lignes-scolaires-gtfs-gtfs-rt/" target="_blank">Horaires théoriques et temps-réel du réseau Annonay - Lignes scolaires (GTFS / GTFS-RT)</a> par <a href="https://www.data.gouv.fr/fr/organizations/zenbus/" target="_blank">Zenbus</a>
# <a href="https://www.data.gouv.fr/fr/datasets/projets-finances-hors-pia-2005-2019-partenaires/" target="_blank">Projets financés (hors PIA) 2005-2019 - Partenaires</a> par <a href="https://www.data.gouv.fr/fr/organizations/agence-nationale-de-la-recherche/" target="_blank">Agence Nationale de la Recherche</a>
# <a href="https://www.data.gouv.fr/fr/datasets/projets-finances-hors-pia-2005-2019/" target="_blank">Projets financés (hors PIA) 2005-2019</a> par <a href="https://www.data.gouv.fr/fr/organizations/agence-nationale-de-la-recherche/" target="_blank">Agence Nationale de la Recherche</a>

# %% [markdown]
# ## Organisations

# %%
show_orgas()
# Out:
# <h3>1 organisations créées</h3>
# <a href="https://www.data.gouv.fr/fr/organizations/agence-nationale-de-la-recherche/" target="_blank">Agence Nationale de la Recherche</a>

# %% [markdown]
# ## Réutilisations

# %%
show_reuses()
# Out:
# <h3>6 réutilisations créées</h3>
# <a href="https://www.data.gouv.fr/fr/reuses/covid-19-exces-de-mortalite-par-departement/" target="_blank">COVID-19 - Excès de mortalité par département</a> par <a href="https://www.data.gouv.fr/fr/users/vianney-dugrain/" target="_blank">Vianney Dugrain</a>
# <a href="https://www.data.gouv.fr/fr/reuses/classement-des-departements-au-28-avril-pour-lintensite-de-lepidemie-avec-une-visualisation-dynamique-de-levolution-depuis-mi-mars/" target="_blank">Classement des départements au 28 avril pour l'intensité de l'épidémie, avec une visualisation dynamique de l'évolution depuis mi-mars</a> par <a href="https://www.data.gouv.fr/fr/users/philippe-garnier/" target="_blank">Philippe Garnier</a>
# <a href="https://www.data.gouv.fr/fr/reuses/lagriculture-bio-en-france-entre-progres-et-consolidation/" target="_blank">L’AGRICULTURE BIO EN FRANCE, ENTRE PROGRÈS ET CONSOLIDATION</a> par <a href="https://www.data.gouv.fr/fr/users/sylvie-souleze/" target="_blank">Sylvie Souleze</a>
# <a href="https://www.data.gouv.fr/fr/reuses/taux-de-deces-par-departement-pour-100000-habitants/" target="_blank">Taux de décès par département pour 100000 habitants</a> par <a href="https://www.data.gouv.fr/fr/users/domie-cat/" target="_blank">Domie CAT</a>
# <a href="https://www.data.gouv.fr/fr/reuses/coronavirusapi-france/" target="_blank">CoronavirusAPI-France</a> par <a href="https://www.data.gouv.fr/fr/users/florian-zemma-gailleton/" target="_blank">Florian Zemma Gailleton</a>
# <a href="https://www.data.gouv.fr/fr/reuses/nutri-score-un-nouveau-logo-nutritionnel-appose-sur-les-produits-alimentaires/" target="_blank">Nutri-score : un nouveau logo nutritionnel apposé sur les produits alimentaires</a> par <a href="https://www.data.gouv.fr/fr/users/sylvie-souleze/" target="_blank">Sylvie Souleze</a>

# %% [markdown]
# ## Discussions

# %%
show_discussions()
# Out:
# <h3>23 commentaires créées</h3>
# Zero new covid-19 cases in French regions starting from 01/04/2020-27/04/2020 sur <a href="https://www.data.gouv.fr/fr/datasets/5e6a3c986f444152b12daadf" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/samah-jradi/" target="_blank">samah JRADI</a>
# <pre>Bonjour,
# I was trying to collect data concerning the new covid-19 cases in french regions. I have noticed that there is a problem with the dataset set of all French region starting from April 1st. The information in Chiffres-cles.csv has zero values for column E concerning the confirmed cases. Could you please check this?
# Thanks for you help, </pre>
# <hr/>
# Evolution au cours du temps sur <a href="https://www.data.gouv.fr/fr/reuses/5e7a97f9cc714d4ffe6f252b" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/romain-m/" target="_blank">Romain M</a>
# <pre>Bonjour,
# Ce serait encore mieux si on pouvait visualiser l'évolution avec un selecteur de date!
# Merci pour cette carte bien réussie!</pre>
# <hr/>
# Evolution au cours du temps sur <a href="https://www.data.gouv.fr/fr/reuses/5e7a97f9cc714d4ffe6f252b" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/vianney-dugrain/" target="_blank">Vianney Dugrain</a>
# <pre>Bonjour,
# Merci pour ce retour et pour la suggestion.
# Malheureusement la plateforme que j'utilise, Carto, ne permet pas d'intégrer un filtre de date dans sa version cloud. Il faudrait utiliser leur API pour faire un développement supplémentaire mais cela nécessiterait un hébergement distinct.</pre>
# <hr/>
# Bientot la fin des hospitalisations Covid19 quid de la suite? des cas testés PCR, IgG...? sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/rina-ralison/" target="_blank">R. Ralison</a>
# <pre>Bonjour,
#
# Il n'y aura bientôt plus d'hospitalisation Covid19 en raison de la baisse des cas.
# Les informations concernant les cas individus testés malades ou immunisés  seront il remontés sur data.gouv.fr ?
#
# Merci</pre>
# <hr/>
# Bientot la fin des hospitalisations Covid19 quid de la suite? des cas testés PCR, IgG...? sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/philippe-bonnin/" target="_blank">philippe bonnin</a>
# <pre>en extrapolant la courbe actuelle des réanimations "bientôt" au niveau national ne serait pas avant fin mai, mais au national ça n'a pas de sens il faut analyser au moins par département
# pour paris par exemple pas avant mi juin
# d'ici là tout peut arriver notamment une reprise mais peu importe les maternelles n'auront pas gachée une année scolaire cruciale pour leur avenir. </pre>
# <hr/>
# Question de compréhension sur les statistiques produites journellement  sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-marie-perette/" target="_blank">Jean-Marie Pérette</a>
# <pre>Bonsoir
# J'ai tenté un travers au travers des données hospitalières, encours d'une part, nouveaux cas d'atre part. Je pose comme règle :
# Total des entrées hôpital + Total des entrées rénimation - total décès - total retour domicile = actuel nombre des patients hospitalisé + actuel solde actuel des patients restant en réanimation. Sur la base des chiffres de 27 soir j'ai 12903 en trop à gauche du signe égal. Je me dis que sans doute ce nombre a été compté une fois en entrée hopital simple et une fois en entrée en réanimation. Qu'en pensez vous?
# </pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-charles-briquet-laugier/" target="_blank">Jean-Charles BRIQUET-LAUGIER</a>
# <pre>Bonjour,
# Je suis à la recherche d'un fichier IRIS 2018 au format geoJSON ou shapefile. Est-ce que ces données sont disponibles en téléchargement ou sur demande. En téléchargeant le fichier j'ai trouvé plusieurs fichiers shapefile (*;shp) sans saisir la différence entre eux.  </pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/matthieu-le-masson/" target="_blank">Matthieu Le Masson</a>
# <pre>Bonjour,
# on a dû rater qqch et la donnée disponible ici (sur data.gouv) n'est pas de la plus grande fraîcheur.
# Les données les plus fraîches sont par là (en shape): https://geoservices.ign.fr/documentation/diffusion/telechargement-donnees-libres.html#contoursiris
# Teasing: la version 2020 est en approche.</pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-charles-briquet-laugier/" target="_blank">Jean-Charles BRIQUET-LAUGIER</a>
# <pre>Merci. J'ai bien téléchargé le fichier contours IRIS compressé disponible à cette adresse : il ne comporte pas de format geoJSON mais plusieurs fichiers Shapefile (shp) dans différents dossiers (exemples : LAMB93_FXX ou encore RGM04UTM385_MYT) dont je n'arrive pas à connaître les différences. Les connaissez-vous ? Quel fichier shapefile dois-je privilégier ?</pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/matthieu-le-masson/" target="_blank">Matthieu Le Masson</a>
# <pre>Re,
# c'est des questions de "territoire" et de projection qui vont avec.
# _FXX = France Metropolitaine
# _MYT=Mayotte
# ...
# Et donc... prenez celui dont vous avez besoin. Si vous êtes sur la metropole, le FXX...
#
# Matthieu (IGN, au fait, j'ai oublié de préciser)</pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-charles-briquet-laugier/" target="_blank">Jean-Charles BRIQUET-LAUGIER</a>
# <pre>Super ! merci beaucoup pour vos réponses rapides. Je pense que nous aurons alors la bonne version. Je vous pose tout de même une question subsidiaire, que je vais essayer d'élucider. Je vais utiliser des statistiques disponibles pour Région Sud : https://notreterritoire.maregionsud.fr qui sont disponibles selon le découpage IRIS 2018. Je dois donc vérifier que le découpage proposé par la Région Sud est le même que celui disponible dans le fichier _FXX (shp). Je pense que oui (ce sont des données INSEE pour les deux) mais est-ce que la liste des IRIS 2018 présentes dans ce fichier métropolitain serait disponible (format csv ou xlsx) afin de comparer les deux listes d'IRIS (Région Sud et INSEE/IGN) ?
# Jean-Charles (Université Côte d'Azur)</pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/matthieu-le-masson/" target="_blank">Matthieu Le Masson</a>
# <pre>Notions de millésimes toujours un peu compliquées...
# Dans le format "shapefile", le fichier avec une extension ".dbf" porte la sémantique des objets. Il s'ouvre avec un tableur quelconque, et vous aurez ainsi accès à la liste des IRIS... Attention, France entière, il y en a 50 000, l'air de rien (et de mémoire).
# Matthieu</pre>
# <hr/>
# IRIS 2018 geoJSON ou shapefile ? sur <a href="https://www.data.gouv.fr/fr/datasets/55424b64c751df766fa7b26f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-charles-briquet-laugier/" target="_blank">Jean-Charles BRIQUET-LAUGIER</a>
# <pre>C'est parfait ! J'ai ouvert le fichier dbf (vous n'étiez pas loin = 48947 IRIS). En faisant un tri et une extraction de tous les IRIS de la Région Sud, je vais pouvoir les comparer à mes données statistiques. Vous m'avez grandement aidé et je vous remercie beaucoup. Bonne continuation.
# Jean-Charles</pre>
# <hr/>
# mis à jour des données sur <a href="https://www.data.gouv.fr/fr/datasets/5e7de8cf4663c08d4f74ba01" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/ronan-perron-1/" target="_blank">Ronan Perron</a>
# <pre>Bonjour,
# Je confirme que les données ne sont plus actualisées depuis 6 jours.
# Pourtant la date de mise est elle actualisée.
# Suite aux discours du 1ier ministre, il semble qu'il ait lui les données!
# Merci de nous tenir informé.
#  </pre>
# <hr/>
# Contours IRIS 2018 sur <a href="https://www.data.gouv.fr/fr/datasets/5c95a61a06e3e710654d34ca" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-charles-briquet-laugier/" target="_blank">Jean-Charles BRIQUET-LAUGIER</a>
# <pre>Bonjour,
# Je cherche les contours IRIS 2018 aux formats GeoJSON ou shapefile. Est-ce que par hasard vous auriez ces données ? Ou pouvez-vous m'indiquer une source qui pourrait me les fournir ?
# Cordialement
# JC Briquet-Laugier</pre>
# <hr/>
# Manque de documentation sur <a href="https://www.data.gouv.fr/fr/datasets/5593aab9c751df35d8a453ba" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/olivia-delporte/" target="_blank">Olivia Delporte</a>
# <pre>Bonjour,
# J'ai vu un message de Brice si dessous qui indique qu'il serait intéressant d'avoir la documentions des variables au format .XLS ?
# Je souhaite effectuer une réutilisation avec des données liés aux normes des restaurants à emporter : https://www.permis-de-exploitation.com/614-l-restauration-a-emporter.html
#
# Merci d'avance pour votre réponse. </pre>
# <hr/>
# Contacts établissements sur <a href="https://www.data.gouv.fr/fr/datasets/5889d03fa3a72974cbf0d5b1" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/oliviera-guillon/" target="_blank">Olivier Guillon</a>
# <pre>Bonjour, la région des Pays de la Loire souhaite automatiser le chargement de données relatives aux lycée depuis les référentiels en open data de l'éducation nationale. J'ai souvenir avoir déjà vu les nom et contacts des responsables d'établissements dans l'un de vos jeux de données mais je ne les trouve plus aujourd'hui; Diffusez-vous toujours ces données en Open data, si non, est-il possible d'accéder à ces données en Close Data depuis votre plateforme ODS ?
# Cordialement,</pre>
# <hr/>
# Je ne trouve pas mon permis de construire dans la liste sur <a href="https://www.data.gouv.fr/fr/datasets/5a5f4f6c88ee387da4d252a3" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/laetitia-blanchet/" target="_blank">laetitia blanchet</a>
# <pre>Bonjour,
#
# Etant dans le même cas que vous, mon permis de construire étant délivré le 20/12/2018, avez vous eu une réponse par téléphone ?
#
# Merci </pre>
# <hr/>
# Fichier REI non anonymisé ? sur <a href="https://www.data.gouv.fr/fr/datasets/58da72bbc751df38734d8658" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/nicolas-alline/" target="_blank">Nicolas Alline</a>
# <pre>Bonjour,
#
# Afin d’effectuer des analyses à la commune ou à l’EPCI, est-il possible de bénéficier du fichier REI non anonymisé ?
#
# Je relève des écarts entre le fichier REI2018 (anonymisé) et le fichier tab410bis_2018 (voir : https://www.data.gouv.fr/fr/datasets/annuaire-statistique/), a priori non soumis au secret statistique.
#
# Par exemple, si je somme les variables CVAEPCOM, CVAEPGFP, CVAEPDEP et CVAEPREG du fichier REI2018, je retrouve le même montant que dans le fichier tab410bis_2018 pour les départements les plus denses (75, 92, 93, …) mais j’observe des écarts plus importants pour d’autres départements.
# Les analyses ne seraient donc valables que pour les départements les plus denses.
#
# Je vous remercie par avance pour votre retour,
#
# Cordialement,
#
# Nicolas ALLINE</pre>
# <hr/>
# Problème fichier tab410bis_2017 sur <a href="https://www.data.gouv.fr/fr/datasets/53698ee1a3a729239d2035bc" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/nicolas-alline/" target="_blank">Nicolas Alline</a>
# <pre>Bonjour,
#
# Il me semble qu'une erreur s’est glissée dans le tableau tab410bis_2017, à minima pour les départements "2X".
# Les lignes seraient décalées. Si on ne s’intéresse qu’aux départements débutant par « 2 », c’est-à-dire de la Corse-du-Sud (2A) au Finistère (29) :
# Actuellement, Corse-du-Sud (2A) et Haute-Corse (2B) affichent une CVAE "payée au profit de l'ensemble des collectivités" de 93 029 et 65 158 milliers d'euros, alors que 14 052 et 14 196 milliers d’euros me semblent être des montants plus cohérents lorsqu’on compare le fichier tab410bis_2017 avec tab410bis_2018 ou avec le fichier REI 2017. Ces deux valeurs (14 052 et 14 196) sont actuellement associées à l'Eure-et-Loir (28) et au Finistère (29), les deux départements en fin de liste.
# Si on rattache les départements 2A et 2B aux valeurs en fin de liste, il faudrait ensuite remonter chaque ligne de deux crans, ce qui donnerait une CVAE de 93 029 milliers d’euros pour la Côte d’Or (21) contre 8 437 actuellement, 65 158 pour les Cotes d’Armor (22) contre 32 791 actuellement, 8 437 pour la Creuse (23) contre 88 781 actuellement, etc…
# Pour information, ces départements affichent une CVAE de 98 151, 65 416 et 8 429 milliers d’euros en 2018 (fichier tab410bis_2018).
# Si le point précédent est vrai, l’erreur s’est malheureusement répercutée sur la synthèse par région.
#
# En vous remerciant par avance pour votre retour,
#
# Nicolas ALLINE</pre>
# <hr/>
# Données OPE sur <a href="https://www.data.gouv.fr/fr/datasets/5bc5c7eb634f41547efbc0c0" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/franck-aguggiaro/" target="_blank">Franck AGUGGIARO</a>
# <pre>Bonjour,
#
# Après avoir dézippé le fichier, le fichier .csv contient énormément de lignes qui peuvent dépassées la capacité de la version du tableur que vous utilisez. Il est conseillé, au vu de la quantité de données, d'utiliser un système de gestion de base de données (SGBD).
# Cordialement
# Franck Aguggiaro</pre>
# <hr/>
# Données OPE sur <a href="https://www.data.gouv.fr/fr/datasets/5bc5c7eb634f41547efbc0c0" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/elisabeth-leclerc/" target="_blank">Elisabeth LECLERC</a>
# <pre>Bonjour Franck,
# Merci  pour votre réponse rapide et tout le travail pour construire cette base de données.
# Cordialement
# Elisabeth
# </pre>
# <hr/>
# Telechargement sur <a href="https://www.data.gouv.fr/fr/datasets/5c4ae55a634f4117716d5656" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/pascal-de-clarens/" target="_blank">pascal de clarens</a>
# <pre>Bonjour,
# J'essaie de télécharger le fichier des mutations immobilières de 2019.
# l'adresse est celle-ci: https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20200416-115822/valeursfoncieres-2019.txt
# La page s'affiche, des lignes sont visibles... mais le telechargement ne se termine pas...
# Après un moment la page redevient blanche, les tentatives de rafraichissement ne font rien...
# merci d'avance pour votre aide
# cordialement</pre>
# <hr/>

# %% [markdown]
# ## Utilisateurs

# %%
show_users()
# Out:
# <h3>95 utilisateurs créés</h3>
# <a href="https://www.data.gouv.fr/fr/users/michele-hugue/" target="_blank">Michèle HUGUE</a>
# <a href="https://www.data.gouv.fr/fr/users/cecile-maillard-salin/" target="_blank">Cécile Maillard-Salin</a>
# <a href="https://www.data.gouv.fr/fr/users/francoise-deshayes/" target="_blank">Françoise Deshayes</a>
# <a href="https://www.data.gouv.fr/fr/users/christine-langlet/" target="_blank">Christine LANGLET</a>
