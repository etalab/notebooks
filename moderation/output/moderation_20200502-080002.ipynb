# %% [markdown]
# **Executed:** Sat May  2 08:00:02 2020<br>**Duration:** 5 seconds.<br>**Autogenerated from:** [/root/notebooks/moderation/moderation.ipynb](output/moderation/moderation_20200502-080002.ipynb)
#
# ---

# %% [markdown]
# # Modération / stats data.gouv.fr
#
# Affiche les derniers objets (datasets, reuses, commentaires, utilisateurs) créés depuis `start_date` (via l'API publique).

# %%
import os
from pathlib import Path

# %%
DOMAIN = 'www.data.gouv.fr'
PAGE_SIZE = 100
current_path = Path(os.getenv('WORKING_DIR')) if os.getenv('WORKING_DIR') else Path().absolute()
fn_path = '%s' % (current_path / 'moderation_fn.ipynb')
# %run $fn_path
# we want everything that happened since this date
start_date = datetime.now() - timedelta(days=1)
start_date
# Out:
# datetime.datetime(2020, 5, 1, 8, 0, 3, 216106)

# %% [markdown]
# ## Jeux de données

# %%
show_datasets()
# Out:
# <h3>1 jeux de données créés</h3>
# <a href="https://www.data.gouv.fr/fr/datasets/2019-historique-des-prix-au-london-fix-once-dor/" target="_blank">2019 Historique des prix au London Fix (Once d'or) </a> par <a href="https://www.data.gouv.fr/fr/users/alexandre-barriol/" target="_blank">Alexandre Barriol</a>

# %% [markdown]
# ## Organisations

# %%
show_orgas()
# Out:
# <h3>5 organisations créées</h3>
# <a href="https://www.data.gouv.fr/fr/organizations/retromirabeau/" target="_blank">retromirabeau</a>
# <a href="https://www.data.gouv.fr/fr/organizations/sasu-immoinov/" target="_blank">SASu IMMOINOV</a>
# <a href="https://www.data.gouv.fr/fr/organizations/startdoc/" target="_blank">STARTDOC</a>
# <a href="https://www.data.gouv.fr/fr/organizations/cashstory/" target="_blank">CashStory</a>
# <a href="https://www.data.gouv.fr/fr/organizations/infonet/" target="_blank">Infonet</a>

# %% [markdown]
# ## Réutilisations

# %%
show_reuses()
# Out:
# <h3>4 réutilisations créées</h3>
# <a href="https://www.data.gouv.fr/fr/reuses/cartographie-de-lactivite-epidemique-par-departement-en-vue-du-deconfinement/" target="_blank">Cartographie de l'activité épidémique par département en vue du déconfinement</a> par <a href="https://www.data.gouv.fr/fr/users/souryvath-nirasay/" target="_blank">Souryvath Nirasay</a>
# <a href="https://www.data.gouv.fr/fr/reuses/covid19-by-gender/" target="_blank">Covid19-by-gender</a> par <a href="https://www.data.gouv.fr/fr/users/bertrand-fournel/" target="_blank">Bertrand Fournel</a>
# <a href="https://www.data.gouv.fr/fr/reuses/quelle-est-la-couleur-de-mon-departement/" target="_blank">Quelle est la couleur de mon département ?</a> par <a href="https://www.data.gouv.fr/fr/users/julien-pornet/" target="_blank">Julien PORNET</a>
# <a href="https://www.data.gouv.fr/fr/reuses/world-situation-room/" target="_blank">World Situation Room</a> par <a href="https://www.data.gouv.fr/fr/organizations/cashstory/" target="_blank">CashStory</a>

# %% [markdown]
# ## Discussions

# %%
show_discussions()
# Out:
# <h3>44 commentaires créées</h3>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/francois-raffin/" target="_blank">François Raffin</a>
# <pre>J’avais donc tout faux....
# Ceci dit et même si je me sus refusé à toute critique jusqu’à présent je crois qu’on commence à nager en plein délire. Le Bas Rhin, environ 150 nouvelles hospitalisations sur la semaine écoulée classé vert pour la circulation du virus, le Lot, max 10 mais probablement 2 ou 3 (il y a un bug dans les chiffres d’hier) classé rouge!!! </pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-pierre-baujot/" target="_blank">Jean-Pierre BAUJOT</a>
# <pre>SVP est ce quelqu'un a trouvé le site officiel de la carte avec les criteres , les valeurs par departement et les cartes ?</pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/sylvain-deriot/" target="_blank">Sylvain Dériot</a>
# <pre>Bonjour,
# Personnellement, je ne comprends pas cet indicateur du pourcentage de passages aux urgences.
# Tout d’abord, « il est robuste et fiable » nous affirme le ministre, en insistant tellement qu’on peut sentir qu’il y’a eu débat interne. Quelques heures après, on nous annonce Qu’il y a des bugs ici et là.
# Ensuite, il s’agit d’un numérateur et d’un dénominateur :
# - sous réserve de corrections des bugs, dont on peut espérer qu’elles soient apportées même si les services des urgences soient souvent débordés et que le nombre de nouveaux hospitalisés subit des fluctuations d’origine administrative, le numérateur devrait effectivement être plutôt fiable
# - le dénominateur me paraît beaucoup plus incertain ; en effet, d’une part il repose sur l'hypothèse selon laquelle le recours aux urgences Est uniforme dans toute la France, ce qui n’est pas acquis compte tenu du fait que le recours aux urgences dépend de l’accès à la médecine générale (cf. Déserts médicaux et agendas Complets) ; d’autre part, on nous explique depuis plusieurs semaines que les gens ne vont plus à l’hôpital de peur d’être contaminés !
# J’espère Sincèrement me tromper et qu’on n’a pas là l’embryon d’un nouveau sketch.
# A suivre.
# Bien cordialement.</pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>explicatirons ici
# https://www.francetvinfo.fr/sante/maladie/coronavirus/coronavirus-decouvrez-la-carte-de-france-du-deconfinement-du-vendredi-1er-mai_3944007.html
#
# le détail est aussi sur data gouv
# https://www.data.gouv.fr/fr/datasets/indicateurs-dactivite-epidemique-covid-19-par-departement/</pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-pierre-baujot/" target="_blank">Jean-Pierre BAUJOT</a>
# <pre>Le détail se limite à  un fichier avec un champ date, un champ département et un champ couleur ?
# Un peu sommaire si on n a pas les éléments permettant de définir la couleur.</pre>
# <hr/>
# Rayon a a 100km sur <a href="https://www.data.gouv.fr/fr/reuses/5e7c7771d9f80f6039da4871" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/alfred-bouq/" target="_blank">Alfred Bouq</a>
# <pre>Bonjour quand je rentre mon adresse il me propose un rayon supérieur à 100 km il vat jusqu’à 160km et ce normal ci la gendarmerie m arrête je leur dit quoi
# Merci pour la réponse</pre>
# <hr/>
# Indicateur activité épidémique COVID-19 sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/philippe-lavenant/" target="_blank">Philippe Lavenant</a>
# <pre>Bonjour Merci pour ces données , avez-vous prévu de mettre en ligne le processus de calcul ( Vert , Rouge ) selon les 2 critères : % de consultation aux urgences + % occupation réanimation. merci
# </pre>
# <hr/>
# Indicateur activité épidémique COVID-19 sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# Quelle est la différence avec la dicussion en dessous?
# Explications ici (et données hier par M. Le Ministre Olivier VERAN)
# https://www.francetvinfo.fr/sante/maladie/coronavirus/coronavirus-decouvrez-la-carte-de-france-du-deconfinement-du-vendredi-1er-mai_3944007.html</pre>
# <hr/>
# Indicateur activité épidémique COVID-19 sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/philippe-lavenant/" target="_blank">Philippe Lavenant</a>
# <pre>Merci pour votre réponse rapide , ce qui m'intéresse est d'accéder aux données source qui établissent les 2 critères  à savoir   :  % de consultation COVID-19 aux urgences et  % de lits occupés en réanimation. Ou trouve-t-on ces données ? A-t-on accès aux données par établissements hospitaliers ? Merci par avance
# </pre>
# <hr/>
# Problème données nb hospi vs communication sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-marie-perette/" target="_blank">Jean-Marie Pérette</a>
# <pre>Pour gommer l'effet des saisies manquantes le we et reportées sur le lundi et mardi j'ai comme notre collègue ci dessus fait une moyenne sur 7 jours, 3 avant et 3 après. Petite difficulté quand on arrive à la fin d'un département, il ne faut pas piocher avec ces 7 jours glissants sur les premières lignes du département suivant..... idem en début et fin de fichier il faut modifier un peu l'algo.
# </pre>
# <hr/>
# Indicateurs COVID 19 - Données hospitalières sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-laurent-1/" target="_blank">Jean LAURENT</a>
# <pre>Bonjour,  Je n'arrive plus à accéder aux indicateurs COVID - données hospitalières postérieurs au 28/04.
# Y a t il eu des restrictions d'accès mises en place ?
# </pre>
# <hr/>
# Indicateurs COVID 19 - Données hospitalières sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jamal-malki/" target="_blank">Jamal MALKI</a>
# <pre>Bonjour Laurent,
# Les indicateurs sont cumulés.
# Autrement dit, le fichier de date D_N contient toutes les données des fichiers de dates < D_N. </pre>
# <hr/>
# Indicateurs COVID 19 - Données hospitalières sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-laurent-1/" target="_blank">Jean LAURENT</a>
# <pre>En fait je parlais de la visibilité des indicateurs de la carte (bloqués au 28/04) mais l'anomalie a été rectifiée ce soir et j'ai pu accéder aux indicateurs du 1 er mai.
# </pre>
# <hr/>
# Quelques erreurs de validation sur <a href="https://www.data.gouv.fr/fr/datasets/5ea1add4a5a7dac3af82310a" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/antoine-augusti/" target="_blank">Antoine Augusti</a>
# <pre>Bonjour,
#
# Le fichier comporte quelques erreurs de validation. Vous pouvez consulter le [rapport en ligne](https://go.validata.fr/table-schema?input=url&schema_url=https://schema.data.gouv.fr/schemas/etalab/schema-stationnement/latest/schema.json&url=https://static.data.gouv.fr/resources/base-nationale-des-lieux-de-stationnement/20200430-143216/20200430-bnls.csv&repair=true)</pre>
# <hr/>
# Quelques erreurs de validation sur <a href="https://www.data.gouv.fr/fr/datasets/5ea1add4a5a7dac3af82310a" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/bergeot-vincent/" target="_blank">Bergeot Vincent</a>
# <pre>De l'encodage en utf 8 ?</pre>
# <hr/>
# Erreur sur <a href="https://www.data.gouv.fr/fr/reuses/5ea9b53ceb249632369b98c4" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/jean-luck/" target="_blank">Jean Luck</a>
# <pre>On ne devrait pas être en orange mais en vert 1 seul lit occupé en réanimation merci de vérifier vis analyse</pre>
# <hr/>
# Erreur sur <a href="https://www.data.gouv.fr/fr/reuses/5ea9b53ceb249632369b98c4" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/helene-tonchia/" target="_blank">Hélène Tonchia</a>
# <pre>De quel département s'agit-il ?
# Il faut regarder les données sur le blog. La carte représente un groupement des départements par la surmortalité calculée par l'Insee. Les courbes ne sont pas calculées par département mais par ce groupement et cela ne prend pas en compte la capacité en réa. Il s'agit uniquement de la circulation et l'erreur sur l'interprétation liée à des anomalies départementales a été compensée par une normalisation de certaines données. </pre>
# <hr/>
# Erreur sur <a href="https://www.data.gouv.fr/fr/reuses/5ea9b53ceb249632369b98c4" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/jean-luck/" target="_blank">Jean Luck</a>
# <pre>Il s agit du département 43 haute Loire </pre>
# <hr/>
# et CHAUVET ? sur <a href="https://www.data.gouv.fr/fr/datasets/536c46d6a3a72933d8d1b3a1" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/michelle-solaro/" target="_blank">michelle solaro</a>
# <pre>dans les repères-peinture de la préhistoire à nos jours, ça commence par Lascaux (- 10.000) et  vous oubliez Chauvet (- 30.000) qui a été découverte il y a plusieurs années - ça va pas votre affaire - allez ! allez !
# </pre>
# <hr/>
# Critères de l'activité épidémique sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/alexandre-duclaux/" target="_blank">Alexandre Duclaux</a>
# <pre>Bonjour et merci pour ce jeu de données. Serait-il possible de disposer également des valeurs des critères de l'activité épidémique : circulation active du virus, tension hospitalière et futurs critères qui seront pris en compte svp ?
# Ceci permettrait d'apporter plus de détail et de justification au classement des départements. Merci</pre>
# <hr/>
# Critères de l'activité épidémique sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-rose/" target="_blank">Fabrice Rose</a>
# <pre>Bonjour, je suis d'accord avec Alexandre. Dans un but pédagogique (ici dans le Cher, beaucoup de personnes ne comprennent pas le niveau rouge), cela permettrait de justifier le classement des départements, notamment le niveau de tension hospitalière qui n'apparaît nulle part aux yeux d'une population qui se croit, de ce fait, protégée. Merci pour ces données.</pre>
# <hr/>
# Critères de l'activité épidémique sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# Vous devriez faire un tour du côté de "données hospitalières" : on y a longuement parlé de la tension
# De plus tout ceci a été expliqué hier par M. Le Ministre de la Santé Olivier VERAN.
# De mémoire : 60% de la capacité initiale, 81 % et au delà des 100%</pre>
# <hr/>
# Critères de l'activité épidémique sur <a href="https://www.data.gouv.fr/fr/datasets/5eaaf07f5abc47e306c5c258" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>explications détaillées ici (en plus je vois que j'ai mis 4 critères et non pas 3 ... : 0 à 60, 60 à 80 et au-delà de 80, les 100% n'ont rien à faire là)
# https://www.francetvinfo.fr/sante/maladie/coronavirus/coronavirus-decouvrez-la-carte-de-france-du-deconfinement-du-vendredi-1er-mai_3944007.html</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Le chiffre de l'Espagne pour le 30/4 est manifestement faux. Erreur de saisie !</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Dans le fichier par Pays le nombre de cas pour l'Espagne évolue comme suit:
# 23/04/2020	Espagne	213024
# 24/04/2020	Espagne	219764
# 25/04/2020	Espagne	223759
# 26/04/2020	Espagne	226629
# 27/04/2020	Espagne	229422
# 28/04/2020	Espagne	232128
# 29/04/2020	Espagne	236899
# 30/04/2020	Espagne	213435
# Outre l'incohérence évidente du chiffre pour le 30/4, il y a une autre incohérence.
# Le ministère espagnol de la santé, annonce lui, 215216 cas pour le 30/4.
# Il y a aussi une différence sur le nombre de morts : 24824 (24543 dans le fichier par pays).
# Toutes ces erreurs à répétition font vraiment désordre !</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>1) Quand on publie des chiffres, il faut faire un minimum de contrôles de cohérence.
# 2) Si on corrige une erreur, il faut au moins l'expliquer au lieu de garder le silence et de maintenir de l'incertitude sur la fiabilité des données.</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/politologue-com/" target="_blank">Politologue .com</a>
# <pre>Je n'ai rien corrigé sur l'Espagne, c'est le CSSE qui produit ces chiffres, mon robot ne fait que prendre ce que le CSSE fournit.
# Je ne sais pas pourquoi hier soir, les cas ont baissé de 23 000
# Les seuls chiffres que j'ajuste chaque soir, c'est les chiffres Français après les annonces.
# Rien ne vous empêche de récupérer les données du CSSE par vos propres moyens, vous aurez les mêmes chiffres, et vous pourrez vous défouler sur vous-même.</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Bonjour
# Je ne me défoule sur personne. j'espère juste avoir des chiffres fiables sur un site officiel. Je ne sais pas ce qu'est le CSSE et je vais me renseigner. De toute façon, je préfère toujours aller à la source des données.
# Je n'ai pas pour autant l'explication des écarts avec le ministère de la santé espagnol.
# Ma réaction, elle aussi liée au fait que je n'ai jamais eu de réponse sur la question que j'avais posée sur le nombre de cas confirmés en France qui inclurait donc le nombre de cas confirmés en ESMS qui comptaient donc deux fois dans la série avant sa correction et dans la présentation du Pr Salomon pendant plusieurs semaines. Mais, bon il faut sans doute fâcher personne.</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/politologue-com/" target="_blank">Politologue .com</a>
# <pre>Le CSSE est la fameuse carte de référence de l’université Johns Hopkins (Je mets cette source en haut de toutes mes pages, il y a juste a suivre le lien, et c'est même mentionné dans cette publication en haut de cette page ainsi que leur dépôt github)
# https://gisanddata.maps.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6
#
# Je viens de découvrir qu'ils ont mis en place un fichier Errata dans le dépôt, je vais voir pour essayer de l'inclure dans mes pages.
# Voici ce qui a été ajouté ces derniers jours :
# 4/30/20,time_series_covid19_deaths_global.csv,United Kingdom,All columns,,,Adjusted all deaths to match newly released data from the United Kingdom identifying deaths in care homes
# 4/30/20,time_series_covid19_cases_global.csv,Spain,4/24-4/29,,,Cases adjusted to match official case count
# 4/30/20,time_series_covid19_recovered_global.csv,Spain,4/26-4/29,,,Recovered adjusted to match official count
#
# Pour ce qui est des cas en France, j'ai réajusté car j'incluais 2 fois les cas confirmés ehpad (qui étaient visiblement inclus dans les cas confirmés), comme cela n'était ni clair ni documenté, je les comptais 2 fois sans le savoir. Quand on m'a donné une explication (même pas officielle mais plus claire) j'ai réajusté.
# De plus en France, cela passe inaperçu, mais il y a quelques jours, le nombre de cas en France a baissé de 3000 environ comme une lettre à la poste, sans réajustement le lendemain ni explication (et avec une infographie publiée au mieux erronée et au pire mensongère. Mais j'ai conservé toutes les publications (infographies et pdf du même jour qui se contredisent...)
# Je suis tout seul à gérer tout ça, si vous voulez avoir ces "infos" sur mes ajustements ou autre, je vous conseille de suivre ma page Facebook ou je consigne tout ça (c'est l'endroit ou je partage le plus de "détails" sur mes travaux sur le sujet)
#
# On fait tous ce que l'on peut pour y voir clair, et c'est vraiment pas simple, ça l'est ni pour vous, ni pour moi. De mon côté j'essaye de partager au mieux toute l'énergie que je mets dans mes recherches pour vous partager au mieux les infos.
# </pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>OK, merci.
# Sur la correction française du 23/4, il y avait un petit commentaire sous la synthèse journalière de Santé Publique France.
# J'étais aussi en train de regarder tout cela sur le site du CSSE. </pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Il y a de quoi s'arracher les cheveux quand on voit que les différentes sources par pays se contredisent. L'UE (ECDPC) et l'OMS donnent encore des chiffres différents.</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/politologue-com/" target="_blank">Politologue .com</a>
# <pre>Bienvenue dans mon monde :) (enfin celui des derniers mois...)</pre>
# <hr/>
# Données grippe espagnole sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Exemple pour l'Espagne le 30/4:
# CSSE (et donc Open Data) :
# 29/4 : 236899
# 30/4 : 213435
# Ministère de la santé espagnol :
# 30/4 : 215216
# UE (ECDPC)
# 28/4 : 210773
# 29/4 : 212917
# OMS : comme UE mais chiffres datés du lendemain
# Pour la France
# Open Data (fichier par pays + détail dans chiffres clés):
# 29/4 : 166420 dont 128442 cas confirmés
# 30/4 : 167178 dont 129581 cas confirmés
# UE (ECDPC)
# 29/4 : 126835
# 30/4 : 128442
# OMS :
# 29/4 : 126835
# 30/4 : 127066</pre>
# <hr/>
# Le jeu de données que je partage n'a rien à voir avec cette réutilisation sur <a href="https://www.data.gouv.fr/fr/reuses/5e956d7512030c5c56728a37" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/politologue-com/" target="_blank">Politologue .com</a>
# <pre>Le jeu de données que je partage n'a rien à voir avec cette réutilisation</pre>
# <hr/>
# Infos manquantes dans le readme sur <a href="https://www.data.gouv.fr/fr/datasets/5e5d89c28b4c410f100c3242" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/yoann-sachot/" target="_blank">Yoann SACHOT</a>
# <pre>Bonjour, il manque dans le readme de présentation du fichier :
# location_horaires
# location_infos
# location_debutInfos
# location_finInfos
#
# Qui sont pourtant présentes dans le CSV.
#
# Bonne journée</pre>
# <hr/>
# Data sur <a href="https://www.data.gouv.fr/fr/reuses/5e8322c135a2a292fd6a29b6" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/lilian-brixy/" target="_blank">Lilian Brixy</a>
# <pre>Bonjour pour un projet (universitaire) je souhaite réaliser un tableau de bord du même type. Malheureusement quand je charge les données (Chiffres clés covid en France) j'ai l'impression qu'il lit les données en faisant une somme du nombre des lignes au lieu de prendre la donnée. Savez-vous comment je peux modifier cela ?
# Je vous remercie </pre>
# <hr/>
# renseigner son établissement sur <a href="https://www.data.gouv.fr/fr/reuses/5e7c7771d9f80f6039da4871" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/alfred-bouq/" target="_blank">Alfred Bouq</a>
# <pre>Bonjour quand je rentre mon adresse il me propose un rayon supérieur à 100 km il vat jusqu'à 160km et ce normal ci la gendarmerie m arrête je leur dit quoi
# Merci pour la réponse </pre>
# <hr/>
# Fichier donnees-hospitalieres-classe-age-covid19-2020-04-30-19h00.csv sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jamal-malki/" target="_blank">Jamal MALKI</a>
# <pre>Pour la date du 2020-04-30, il manque le fichier : donnees-hospitalieres-classe-age-covid19-2020-04-30-19h00.csv
# </pre>
# <hr/>
# Les données hospitalières quotidiennes relatives à l'épidémie du COVID-19 par département du patient :  sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# Quel lien voulez-vous faire entre nouveaux hosp et nouveaux réa? Les personnes admises  à l'hôpital sont pour la très grande majorité des gens conscients, qui viennent sur leurs 2 jambes (quelques cas ont été remontés, de Paris, probablement parce que les journalistes interviewent des médecins à Paris, c'est plus simple et ça respecte le confinement, qui sont arrivés directement en réa)
# Les personnes qui rentrent en réa sont des personnes dont l'état s'est dégradé au bout de quelques jours : 2?, 3?, 5? ...
# Il n'y a donc pas de lien direct entre 15 personnes qui sont comptabilisées comme "nouvelles hosp" et les nouveaux "réa"
# Pas directement en tout cas : si on a 15 nouvelles hosp et 3 nouvelles réa, les 3 nouvelles réa peuvent très bien être 3 personnes déjà hospitalisées depuis 1 semaine pour la plus 'ancienne' des 3.
# Par contre, bien sûr que les nouveaux réa sont dans "somme des nouveaux hosp". D'où peuvent-elles venir ailleurs? Au iota que j'ai signalé juste avant de ceux qui rentrent directement en réa mais qui sont une minorité.
# Et c'est bien là le souci : on ne sait pas d'où viennent les réa, comme les réa sont ventilés : retournent-ils en hosp? sont-ils décédés? rentrent-ils chez eux (peu probable qu'on passe de réa à la maison sans repasser par hosp), viennent-ils de hosp?
# Et c'est ce que demande M. BAUJOT (et d'autres) depuis le tout début. Mais sans retour.
# Ce qui est sûr en tout cas, c'est qu'il ne faut pas faire la somme "incid hosp + incid réa" pour avoir les nouvelles entrées du jour. Encore que : ça dépend de ce que vous cherchez à déterminer : si c'est le nombre de personnes pour gérer ces "flux" alors il faut faire la somme des 2 cas (plus il y a de cas hosp et réa, plus il faut de monde pour remonter les chiffres que nous traitons)</pre>
# <hr/>
# Les données hospitalières quotidiennes relatives à l'épidémie du COVID-19 par département du patient :  sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fichen-yvon/" target="_blank">Fichen Yvon</a>
# <pre>Merci Denis pour ta réponse
# Je reformule ma question pour les flux quotidiens.
# - le 18 un malade entre à l'hôpital : il fait +1 à incid_hop (je présume)
# - le 20 ça s'aggrave il passe en réa : il fait +1 à incid_rea (je présume)
# Mon interrogation : est que le 20 il fait aussi -1 à incid_hop ?
# - si OUI il faut ajouter incid_hop à incid_rea pour avoir le nombre de patients nouveaux
# - si NON il faut considérer seulement incid_hop comme patients nouveaux (et espérer que peu de patients passent en rea sans passer à la case hop).
# Merci de m'éclairer.
# </pre>
# <hr/>
# Les données hospitalières quotidiennes relatives à l'épidémie du COVID-19 par département du patient :  sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/yoch-melka/" target="_blank">Josué Melka</a>
# <pre>Il y a plusieurs fichiers. Celui intitulé **donnees-hospitalieres-nouveaux-covid19** recense les nouveaux cas (c'est d'ailleurs la définition de l'incidence en épidémiologie), donc la réponse devrait être NON.</pre>
# <hr/>
# Les données hospitalières quotidiennes relatives à l'épidémie du COVID-19 par département du patient :  sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>bien que n'étant pas certain à 100% (95?) je ne pense pas : il s'agit de nouvelles admissions. On ne compte pas la sortie.
# La personne admise en réa n'est pas sortie du système hospitalier. Elle occupe toujours 1 lit d'hospitalisation. Certes c'est un lit de réa mais ça n'est pas un lit de plus. Ou de moins.
# Un hôpital a 100 lits. Dont 20 sont des lits pouvant accueillir des patients en service de réanimation.
# ça ne fait pas 120 lits. Rien n'oblige le lit de réa d'accueillir des personnes ayant besoin de réa : si les 80 lits non réa sont occupés, on prendra un lit de réa pour y mettre quelqu'un, quitte à ne pas se servir du matériel de réa.
# On pourrait compter 80 lits + 20 lits de réa. Mais l'hôpital a bien 100 lits. Pas 80.</pre>
# <hr/>
# Doc inaccessible sur <a href="https://www.data.gouv.fr/fr/reuses/59385f1388ee382cd863e8fe" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/thibaud-zerr/" target="_blank">thibaud zerr</a>
# <pre>Bonjour,
# Lien vers la documentation complète ne fonctionne pas correctement;
# Bien a vous
# TZ</pre>
# <hr/>
# Data de test par les hôpitaux sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# C'est la colonne nbre_hospit_corona
# Il est effectivement indiqué que c'est "suspicion". Mais si vous avez suivi l'épidémie depuis le début, les médecins envoyaient des patients à l'hôpital qui n'étaient pas atteint du covid-19. ça n'arrive quasiment plus.
# Tout dépend de votre besoin : si vous voulez le nombre exact de personnes testées à l'hôpital, ça ne vous suffit peut-être pas.
# Pour autant : le chiffre remonté par le fichier sursaud de personnes 'suspectées' est de 123339
# Le gouvernement remonte 129581</pre>
# <hr/>

# %% [markdown]
# ## Utilisateurs

# %%
show_users()
# Out:
# <h3>111 utilisateurs créés</h3>
# <a href="https://www.data.gouv.fr/fr/users/firat-celebi/" target="_blank">Firat celebi</a>
# <a href="https://www.data.gouv.fr/fr/users/strella-ahn/" target="_blank">Strella Ahn</a>
# <a href="https://www.data.gouv.fr/fr/users/yvon-corbier/" target="_blank">yvon CORBIER</a>
# <a href="https://www.data.gouv.fr/fr/users/frederic-linck/" target="_blank">Frédéric  Linck</a>
# <a href="https://www.data.gouv.fr/fr/users/radionoff-sophie/" target="_blank">RADIONOFF Sophie</a>
# <a href="https://www.data.gouv.fr/fr/users/denis-soyer/" target="_blank">denis soyer</a>
# <a href="https://www.data.gouv.fr/fr/users/jacqueline-pamart/" target="_blank">Jacqueline Pamart</a>
# <a href="https://www.data.gouv.fr/fr/users/maryam-ait-lmouden/" target="_blank">MARYAM ait lmouden</a>
# <a href="https://www.data.gouv.fr/fr/users/jean-pedro-maignan/" target="_blank">Jean-Pedro MAIGNAN</a>
# <a href="https://www.data.gouv.fr/fr/users/bachir-adem/" target="_blank">bachir adem</a>
# <a href="https://www.data.gouv.fr/fr/users/frank-wittendal/" target="_blank">Frank Wittendal</a>
# <a href="https://www.data.gouv.fr/fr/users/maxime-hubert/" target="_blank">Maxime Hubert</a>
# <a href="https://www.data.gouv.fr/fr/users/seb-cc/" target="_blank">Seb Cc</a>
# <a href="https://www.data.gouv.fr/fr/users/emmelie-gree/" target="_blank">Emmélie Grée</a>
# <a href="https://www.data.gouv.fr/fr/users/virgil-trannois/" target="_blank">Virgil Trannois</a>
# <a href="https://www.data.gouv.fr/fr/users/patrick-galland/" target="_blank">Patrick GALLAND</a>
# <a href="https://www.data.gouv.fr/fr/users/anya-yabas/" target="_blank">Anya YABAS</a>
# <a href="https://www.data.gouv.fr/fr/users/gerard-niel/" target="_blank">Gerard Niel</a>
# <a href="https://www.data.gouv.fr/fr/users/laurent-gachet/" target="_blank">Laurent Gachet</a>
