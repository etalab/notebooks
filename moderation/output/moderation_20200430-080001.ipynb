# %% [markdown]
# **Executed:** Thu Apr 30 08:00:01 2020<br>**Duration:** 14 seconds.<br>**Autogenerated from:** [/root/notebooks/moderation/moderation.ipynb](output/moderation/moderation_20200430-080001.ipynb)
#
# ---

# %% [markdown]
# # Modération / stats data.gouv.fr
#
# Affiche les derniers objets (datasets, reuses, commentaires, utilisateurs) créés depuis `start_date` (via l'API publique).

# %%
import os
from pathlib import Path

# %%
DOMAIN = 'www.data.gouv.fr'
PAGE_SIZE = 100
current_path = Path(os.getenv('WORKING_DIR')) if os.getenv('WORKING_DIR') else Path().absolute()
fn_path = '%s' % (current_path / 'moderation_fn.ipynb')
# %run $fn_path
# we want everything that happened since this date
start_date = datetime.now() - timedelta(days=1)
start_date
# Out:
# datetime.datetime(2020, 4, 29, 8, 0, 2, 663975)

# %% [markdown]
# ## Jeux de données

# %%
show_datasets()
# Out:
# <h3>9 jeux de données créés</h3>
# <a href="https://www.data.gouv.fr/fr/datasets/challenge-metropolitain-du-velo-volume-de-trajets-2013-2019/" target="_blank">Challenge Métropolitain du Vélo - Volume de trajets - 2013-2019</a> par <a href="https://www.data.gouv.fr/fr/organizations/metropole-europeenne-de-lille/" target="_blank">Métropole Européenne de Lille </a>
# <a href="https://www.data.gouv.fr/fr/datasets/prive-offre-deconfinement/" target="_blank">PRIVE - Offre déconfinement</a> par <a href="https://www.data.gouv.fr/fr/organizations/saemes/" target="_blank">Saemes </a>
# <a href="https://www.data.gouv.fr/fr/datasets/spc-smyl-qmoy-2/" target="_blank">SPC-SMYL-QMOY</a> par <a href="https://www.data.gouv.fr/fr/users/spc-idf-1/" target="_blank">SPC IDF</a>
# <a href="https://www.data.gouv.fr/fr/datasets/irve-ccphva/" target="_blank">IRVE_CCPHVA</a> par <a href="https://www.data.gouv.fr/fr/users/salim-el-rhazi/" target="_blank">Salim EL RHAZI</a>
# <a href="https://www.data.gouv.fr/fr/datasets/lieux-proposant-des-masques-ou-du-gel-hydro-alcoolique/" target="_blank">Lieux proposant des masques ou du gel hydro-alcoolique</a> par <a href="https://www.data.gouv.fr/fr/organizations/ca-reste-ouvert/" target="_blank">Ça reste ouvert</a>
# <a href="https://www.data.gouv.fr/fr/datasets/debits-moyens/" target="_blank">Debits moyens</a> par <a href="#" target="_blank">- orphan -</a>
# <a href="https://www.data.gouv.fr/fr/datasets/certification-des-comptes-2019-de-letat/" target="_blank">Certification des comptes 2019 de l’État </a> par <a href="https://www.data.gouv.fr/fr/organizations/cour-des-comptes/" target="_blank">Cour des comptes</a>
# <a href="https://www.data.gouv.fr/fr/datasets/le-budget-de-letat-en-2019-resultats-et-gestion/" target="_blank">Le budget de l’État en 2019 (résultats et gestion) </a> par <a href="https://www.data.gouv.fr/fr/organizations/cour-des-comptes/" target="_blank">Cour des comptes</a>
# <a href="https://www.data.gouv.fr/fr/datasets/r0-vitesse-de-propogation-coronavirus-covid19-departements-incl-paris/" target="_blank">R0 (vitesse de propogation) Coronavirus Covid19 départements incl Paris</a> par <a href="https://www.data.gouv.fr/fr/users/jeremy-boyd/" target="_blank">Jeremy Boyd</a>

# %% [markdown]
# ## Organisations

# %%
show_orgas()
# Out:
# <h3>4 organisations créées</h3>
# <a href="https://www.data.gouv.fr/fr/organizations/excel-place-excel-certification/" target="_blank">Excel Place (Excel Certification)</a>
# <a href="https://www.data.gouv.fr/fr/organizations/nkonsulting/" target="_blank">NKonsulting</a>
# <a href="https://www.data.gouv.fr/fr/organizations/sofa-tantra/" target="_blank">Sofa tantra</a>
# <a href="https://www.data.gouv.fr/fr/organizations/commune-de-saint-porquier/" target="_blank">Commune de Saint Porquier</a>

# %% [markdown]
# ## Réutilisations

# %%
show_reuses()
# Out:
# <h3>2 réutilisations créées</h3>
# <a href="https://www.data.gouv.fr/fr/reuses/tendance-modelisee-par-surmortalite-departementale-pour-le-deconfinement/" target="_blank">Tendance modélisée par surmortalité départementale pour le déconfinement</a> par <a href="https://www.data.gouv.fr/fr/users/helene-tonchia/" target="_blank">Hélène Tonchia</a>
# <a href="https://www.data.gouv.fr/fr/reuses/covid-tracker-suivez-lepidemie-du-covid19-en-france-et-dans-le-monde/" target="_blank">Covid Tracker : suivez l'épidémie du Covid19 en France et dans le monde !</a> par <a href="https://www.data.gouv.fr/fr/users/guillaume-rozier/" target="_blank">Guillaume Rozier</a>

# %% [markdown]
# ## Discussions

# %%
show_discussions()
# Out:
# <h3>36 commentaires créées</h3>
# Classe d'age: données rétrospectives ajoutées sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-pierre-baujot/" target="_blank">Jean-Pierre BAUJOT</a>
# <pre>Très juste , je ne regardais que les derniers jours pour voir les tendances !
# Du coup, je note une anomalie sur la classe age 9  entre le 6 et les 7 avril , les chiffres dans toutes les catégories étaient positifs  et brutalement au 7/4 tout passe à 0?</pre>
# <hr/>
# Classe d'age: données rétrospectives ajoutées sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/yoch-melka/" target="_blank">Josué Melka</a>
# <pre>En effet, c'est assez étrange. Soit il n'y a plus aucun cas depuis en dessous de 10 ans (mais on aurait dû voir les RAD supplémentaires le 07), soit ils ne publient plus les données pour cette tranche d'age.
#
# Autre remarque: en étudiant les variation du décalage entre la somme des classes d'ages et la classe 0, on se rend compte qu'il y a un écart soudain sur les RAD entre le 06/04 et le 07/04 (la différence passe de 173 à 482).
# </pre>
# <hr/>
# Classe d'age: données rétrospectives ajoutées sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-pierre-baujot/" target="_blank">Jean-Pierre BAUJOT</a>
# <pre>c'est vrai et comme on passe de 266 à 0  en RAD pour la tranche 9  ca explique une bonne partie de l'écart sur le 7
# pour les hosp pour la tranche 9 on passe aussi de 83 à 0, ce qui explique aussi le sursaut des hosp
# mais en plus l'écart n'arrête pas d'augmenter avec une pente importante pour les RAD , actuellement environ 900 personnes en RAD sans info sur leur age ....</pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/sylvain-deriot/" target="_blank">Sylvain Dériot</a>
# <pre>Bonjour,
# Le classement des départements sera établi selon 3 critères. Les 1er est le « taux de cas nouveaux sur la population ».
# Savez vous si ce taux est :
# - le nombre Quotidien de nouvelles hospitalisations, ramené ou pas au nombre d’habitants du département
# - une estimation du nombre quotidien total de nouveaux cas (hospitalisés + consultés par des médecins + asymptomatiques), ramené ou pas au nombre d’habitants du département ; cette estimation risque d’être sujette à caution et constations...
# Bien cordialement </pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/sylvain-deriot/" target="_blank">Sylvain Dériot</a>
# <pre>Correctif : ´contestations’ et non ´constations’</pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-michel-hoarau/" target="_blank">jean michel hoarau</a>
# <pre>Il me semble que pour le nombre de nouveaux cas testés , ce sera au niveau national  (moins de 3000 dans l'exemple donné par E.P. pour  le déconfinement soit appliqué normalement).
# Pour les départements il s'agit plutot des seuils de capacités d'accueil d'hospitalisation et de réas . Le taux maximal pour etre dans le vert n'a pas été précisé...mais il devrait l'etre à partir de demain soir , par J Salomon , la date butoir étant fixée au 7/05.</pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/francois-raffin/" target="_blank">François Raffin</a>
# <pre>Personnellement je pense qu’il s’agit d’une estimation du nombre de nouvelles contaminations quotidiennes en utilisant les résultats de l’étude de l’Institut Pasteur/Inserm selon laquelle 2,6% des personnes infectées sont hospitalisées. Cette étude prévoyait un nombre d’infections quotidiennes dans une fourchette 830-2300 à l’horizon 11 mai ce qui au vu de l’évolution des chiffres depuis cette date paraît quelque peu optimiste. </pre>
# <hr/>
# Le critère ´taux de cas nouveaux sur la population’ sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-michel-hoarau/" target="_blank">jean michel hoarau</a>
# <pre>edit :j'ai omis le qualificatif "positif  donc:  nouveaux cas testés positifs  ..;qui devront etre inferieur à 3000 au 7 mai.</pre>
# <hr/>
# Question de compréhension sur les statistiques produites journellement  sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-pierre-baujot/" target="_blank">Jean-Pierre BAUJOT</a>
# <pre>comme les réa sont inclus dans les hospitalisations , je ne comprends pas votre calcul ?
# on peut juste faire un calcul en retirant les rea des 2 cotés </pre>
# <hr/>
# Je ne trouve pas mon permis de construire dans la liste sur <a href="https://www.data.gouv.fr/fr/datasets/5a5f4f6c88ee387da4d252a3" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/benoit-dumas-chaumette/" target="_blank">Benoit Dumas Chaumette</a>
# <pre>Bonjour,
#
# Oui nous avons eu une réponse (on a appelé avant le confinement), selon eux ça n'arrive jamais nous n'avons pas eu de chance car notre numéro de permis comporte un petite particularité qui a fait que c'était impossible de s'enregistrer en ligne. J'ai un tout petit peu de mal à les croire..... enfin bon depuis on a fait ce qu'ils nous ont demandé et on attend.</pre>
# <hr/>
# Je ne trouve pas mon permis de construire dans la liste sur <a href="https://www.data.gouv.fr/fr/datasets/5a5f4f6c88ee387da4d252a3" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/laetitia-blanchet/" target="_blank">laetitia blanchet</a>
# <pre>Merci de votre retour </pre>
# <hr/>
# demande d'éclaircissement sur l'origine de ces données sur <a href="https://www.data.gouv.fr/fr/datasets/5e7de8cf4663c08d4f74ba01" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/rina-ralison/" target="_blank">R. Ralison</a>
# <pre>Bonjour,
#
# C'est plutôt rassurant de voir que des données sur les tests soient disponibles ici.
# Néanmoins je suis très étonné que ces données existent dans la mesure où il est de notoriété publique qu'il n'y a plus de réactif et de matériel de prélèvement.
# Donc la question est sur qui ces test ont été éfféctués?
# Des amis proches ayant eu les symptômes du covid19 à leur domicile n'ont jamais été testé, d'où mon étonnement sur ces données.
#
# Par ailleurs, données  les laboratoires vétérinaires </pre>
# <hr/>
# Demande nb de logements - capacités par entité ou département sur <a href="https://www.data.gouv.fr/fr/datasets/586dae74a3a7290df6f4bea1" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/isabelle-bonnelie/" target="_blank">Isabelle Bonnélie</a>
# <pre>Bonjour,
# Dans le cadre de la stratégie de déconfinement, j'aurais besoin du nb de logements (places) par département (ou résidence). En disposez-vous ?
# Cordialement,
# Isabelle Bonnélie</pre>
# <hr/>
# Nb de logements par catégorie sur <a href="https://www.data.gouv.fr/fr/datasets/5548d994c751df32e0a7b26c" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/isabelle-bonnelie/" target="_blank">Isabelle Bonnélie</a>
# <pre>Bonjour,
# Dans le cadre du déconfinement, j’aurais besoin du nb de logements (places) par département ou résidence. En disposez-vous ?
# Cordialement,</pre>
# <hr/>
# Erreur pour la France dans le fichier par pays. sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Personne n'ayant répondu à mes questions précédentes, je me suis rallié à l'hypothèse de Daniel Tolbiac selon laquelle le nombre de cas confirmé incluait les cas confirmé en ESMS et que donc la série recalculée pour la France dans le fichier par pays ne devait y ajouter que les cas possibles en ESMS.
# Mais aujourd'hui pour le 28/4 on a une erreur.
# Le fichier des chiffres-clé donne :
# Cas confirmés : 129.859
# Cas possibles en ESMS : 39076
# Soit un total de 168.935
# Le fichier par pays donne lui : 165.911
# </pre>
# <hr/>
# Erreur pour la France dans le fichier par pays. sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Désolé pour les coquilles en écrivant vite : lire "cas confirmés"</pre>
# <hr/>
# Erreur pour la France dans le fichier par pays. sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Dommage de ne pas pouvoir modifier ou supprimer un commentaire.</pre>
# <hr/>
# Erreur pour la France dans le fichier par pays. sur <a href="https://www.data.gouv.fr/fr/datasets/5e5da8356f44412b1755a8f6" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fabrice-dalpayrat/" target="_blank">Fabrice DALPAYRAT</a>
# <pre>Santé publique France vient de reconnaître une erreur pour le 27/4.
# Le chiffre du nombre de cas est faux pour le 27 et le 28 dans le fichier des chiffres clés et reste faux pour le 27/11 dans le fichier par pays..</pre>
# <hr/>
# Bogue ? sur <a href="https://www.data.gouv.fr/fr/reuses/5e0cf0a28b4c41122cc4ca58" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/jp-groult/" target="_blank">jp groult</a>
# <pre>Un grand MERCI à FABIEN ANTOINE et Compliments.
# pour son travail....... mis à disposition des internautes.......... GRATUITEMENT/. Pas si évident, la gratuité !</pre>
# <hr/>
# Bogue ? sur <a href="https://www.data.gouv.fr/fr/reuses/5e0cf0a28b4c41122cc4ca58" target="_blank">Reuse</a> par <a href="https://www.data.gouv.fr/fr/users/fabien-antoine/" target="_blank">Fabien Antoine</a>
# <pre>Merci beaucoup @jp groult !
# @Maxime, le bug est résolu (depuis quelques temps), on peut même aller à la dernière page sur les pages de plus de 10M d'enregistrements. N'hésitez pas à commenter de nouveau s'il y a un nouveau problème !</pre>
# <hr/>
# Signification valeur 0 dans les indicateurs + nombre maximum de niveaux sur <a href="https://www.data.gouv.fr/fr/datasets/5a5f4f6c88ee387da4d252a3" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/fanny-chopot/" target="_blank">Fanny Chopot</a>
# <pre>Bonjour,
#
# Mes questions concernent les logements :
# 1) Je retrouve très souvent la valeur 0 dans les indicateurs telles l'utilisation personnelle / vente / location, la construction des annexes (piscine, garage, ...), ou encore la nature de la résidence (adapté aux personnes âgées, étudiants, ...). Que signifie en réalité cette valeur ? Est-elle une négation ? Ou cela peut vouloir aussi dire que ce n'est "pas renseigné / déclaré" ?
# 2) La variable nombre maximum de niveaux concerne uniquement les niveaux "hors sol", ou les niveaux sous sol sont-elles aussi comprises ?
#
# Merci d'avance pour vos réponses et bonne fin de journée,
# Cordialement.
#
#
# Fanny CHOPOT</pre>
# <hr/>
# demande de précisions sur <a href="https://www.data.gouv.fr/fr/datasets/5d3821d1634f412bf0a3f28f" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/moussu-fabrice/" target="_blank">Moussu Fabrice</a>
# <pre>Bonjour, je réalise une thèse professionnelle dans le cadre de mes études sur la règlementation thermique. J'essaye d'exploiter les données DPE  (https://www.data.gouv.fr/fr/datasets/diagnostics-de-performance-energetique-pour-les-logements/). J'observe que le champs des années de construction est mal renseigné avec beaucoup de données vides ou incohérentes. Par ailleurs, vous mettez pas à notre disposition de détails sur les champs "type" de façon à connaître la nomenclature et traiter les données. A votre disposition pour échanger sur le sujet. Cdt</pre>
# <hr/>
# données 2019 sur <a href="https://www.data.gouv.fr/fr/datasets/53698f4ca3a729239d2036df" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/marin-leroy/" target="_blank">Marin Leroy</a>
# <pre>C'est bien ce qu'il me semblait, merci de votre réponse.</pre>
# <hr/>
# données 2019 sur <a href="https://www.data.gouv.fr/fr/datasets/53698f4ca3a729239d2036df" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/roger-nicholls/" target="_blank">Roger Nicholls</a>
# <pre>Je pense avoir lu cette semaine que les données de 2019 ne seront pas mises en ligne avant novembre....?  Tiens tiens, trop tard pour faire arrêter le 80k/h ... </pre>
# <hr/>
# Evolution fichiers COG 2018-2019 sur <a href="https://www.data.gouv.fr/fr/datasets/58c984b088ee386cdb1261f3" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/lucie-nahassia/" target="_blank">Lucie Nahassia</a>
# <pre>Bonjour,
#
# Concernant les modifications de fichiers et de formats ayant eu lieu entre le millésime 2018 et le millésime 2019, pouvez-vous me confirmer qu'en plus des changements mentionnés ici, le fichier "Liste des communes de la métropole et Dom (toutes les communes ayant existé depuis 1943)" n'est plus fourni à partir du millésime 2019 ?
#
# Merci d'avance,
# Lucie Nahassia - Arcep</pre>
# <hr/>
# Data de test par les hôpitaux sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# Sont-ce celles-ci que vous cherchez? : Données des urgences hospitalières et de SOS médecins relatives à l'épidémie de COVID-19
# Disponibles ici : https://www.data.gouv.fr/fr/datasets/donnees-des-urgences-hospitalieres-et-de-sos-medecins-relatives-a-lepidemie-de-covid-19/</pre>
# <hr/>
# Data de test par les hôpitaux sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/jean-daunizeau/" target="_blank">JEAN DAUNIZEAU</a>
# <pre>Bonjour,
# Merci pour votre réponse.
# Euh... je ne crois pas que les données des urgences hospitalières et de SOS médecins contiennent un décompte des test-COVID effectués en hôpital (analogues aux tests effectués en laboratoires de ville). En tous cas, cela ne semble pas le cas, d'après les metadonnées. Ou ai-je manqué quelque chose?
# Cordialement</pre>
# <hr/>
# Prestations liées à l'hospitalisation  sur <a href="https://www.data.gouv.fr/fr/datasets/54de1e8fc751df388646738b" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/anne-emmanuelle-adou/" target="_blank">Anne Emmanuelle Adou</a>
# <pre>Bonjour Madame,
# Merci beaucoup pour toutes ces précisions.
# Est-ce qu’il y a des raisons particulières pour lesquelles les données d’hospitalisation du secteur public sont absentes de la base ?
# Il y a-t-il un moyen d’avoir accès à ces données (anonymisées bien sûr) ?
# En vous remerciant d’avance pour votre retour,
# Bien cordialement,
# </pre>
# <hr/>
# Gros écart entre les données hospitalières et le dashboard du gouvernement (et SPF) sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# Hier si on fait le cumul des données on trouve 14676 décès. Le site du gouvernement et SPF indique 14810. Écart de 134. C'est la 1e fois depuis le début (18 Mars) que nous avons un tel écart. Il était même à 0 jusqu'au 15 avril puis est passé à 8 puis à 11 et maintenant 134.
# Il en est de même pour les rad : 564 d'écart alors qu'on n'avait jamais dépassé 7.
# D'où viennent ces écarts? La méthode de calcul aurait changé? Rattrapage d'anomalies?</pre>
# <hr/>
# Gros écart entre les données hospitalières et le dashboard du gouvernement (et SPF) sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/sylvain-deriot/" target="_blank">Sylvain Dériot</a>
# <pre>Serait ce dû aux décès en milieu hospitalier de personnes résidant en instituts sociaux et médico-sociaux (EHPAD par ex) ? En effet, il me semble que SPF les prend en compte dans le nombre de décès dans les hôpitaux tandis que la DGS les considère comme décès dans les instituts sociaux et médico-sociaux.</pre>
# <hr/>
# Dictionnaire de variables sur <a href="https://www.data.gouv.fr/fr/datasets/5530fbacc751df5ff937dddb" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/clemence-berson/" target="_blank">Clémence Berson</a>
# <pre>Bonjour,
# Est-il possible d'avoir un dictionnaire des variables de la BAN ? La plupart des variables sont transparentes mais x et y sont un peu plus difficiles à interpréter.
# Merci</pre>
# <hr/>
# Données SIRENE 2012 sur <a href="https://www.data.gouv.fr/fr/datasets/5b7ffc618b4c4169d30727e0" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/hugo-dassenza-david/" target="_blank">Hugo d'Assenza-David</a>
# <pre>Dans le cadre d'un projet de recherche universitaire, nous avons besoin de variables issues de différents registres officiels. Pour des raisons méthodologiques, l'ensemble des informations doivent dater de l'année 2012. Ne trouvant pas ces informations pour le fichier SIRENE à l'année 2012 ni sur le site https://www.data.gouv.fr/fr/, ni sur le réseau Quételet, je me suis permis de vous contacter directement.
#
# Serait-ce possible d'avoir un accès à ces données ?
#
# Bien entendu, nous nous conformerions aux exigences que vous formulerez. Je pense par exemple à la non-utilisation pour un motif commercial, la non-diffusion à un personne tierce ou encore la non-utilisation pour un autre projet de recherche.
#
# J'espère que vous pourrez traiter ma demande, votre aide serait d'une grande utilité. Je suis bien entendu à votre disposition si vous souhaitez davantage d'information par rapport à ma demande.
# Vous pouvez me contacter par mél à l'adresse hugo.dassenza-david@glasgow.ac.uk.
#
# Bien cordialement,
# </pre>
# <hr/>
# Données SIRENE 2012 sur <a href="https://www.data.gouv.fr/fr/datasets/5b7ffc618b4c4169d30727e0" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/diffusion-sirene-insee/" target="_blank">Diffusion Sirene Insee</a>
# <pre>Bonjour. Nous ne répondons sur ce site qu’aux questions relatives aux données qui y sont diffusées, Nous vous invitons à formuler votre demande sur le site insee,fr (https://www.insee.fr/fr/information/1302169)
# Bien cordialement.
# Pour vous abonner à notre lettre d’information Sirene open data actualités, suivez ce lien : https://insee.fr/fr/information/1405555 Pour consulter nos lettres d’informations, suivez ce lien : https://www.insee.fr/fr/information/3711739 </pre>
# <hr/>
# Fichier ICPE - 2012 sur <a href="https://www.data.gouv.fr/fr/datasets/5d8da992634f414b1c98117b" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/hugo-dassenza-david/" target="_blank">Hugo d'Assenza-David</a>
# <pre>Monsieur,
#
# Je vous envoie cette question en tant qu'affilié de recherche au Urban Big Data Centre, un centre rattaché à l'université de Glasgow.
# Dans le cadre d'un projet de recherche, nous avons besoin de variables issues de différents registres officiels. Pour des raisons méthodologiques, l'ensemble des informations doivent dater de l'année 2012. Ne trouvant pas ces informations pour le fichier ICPE pour l'année 2012 ni sur le site https://www.data.gouv.fr/fr/, ni sur le réseau Quételet, je me suis permis de vous contacter directement.
#
# Est-ce que vous sauriez dans quelle mesure est-ce que je pourrais les récupérer ? Si vous ne disposez pas de ces données, savez-vous vers qui nous pourrions nous tourner pour les obtenir ?
# J'espère que vous pourrez traiter ma demande, votre aide serait d'une grande utilité. Je suis bien entendu à votre disposition si vous souhaitez davantage d'information par rapport à ma demande.
# Vous pouvez me contacter par mél à l'adresse hugo.dassenza-david@glasgow.ac.uk
#
# Bien cordialement,
# Hugo d'Assenza-David
# </pre>
# <hr/>
# Données infections par jour + erreur sur le fichier metadonnées sexe sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users/denis-arnaud/" target="_blank">Denis ARNAUD</a>
# <pre>Bonjour,
#
# Comme déjà indiqué dans ce dataset, le réseau sentinelle n'a été activé que le 17 mars. Les données officielles ne peuvent donc pas être antérieures.</pre>
# <hr/>
# Bientot la fin des hospitalisations Covid19 quid de la suite? des cas testés PCR, IgG...? sur <a href="https://www.data.gouv.fr/fr/datasets/5e7e104ace2080d9162b61d8" target="_blank">Dataset</a> par <a href="https://www.data.gouv.fr/fr/users